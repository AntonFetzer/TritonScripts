# %% [markdown]
# # Pandas Lesson

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"
titanic = pd.read_csv(url, index_col='Name')

# %%
print(titanic)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(titanic.groupby("Survived")["Age"].mean())
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
titanic.hist(column='Age', by='Survived', bins=25, figsize=(8,10),
             layout=(2,1), zorder=2, sharex=True, rwidth=0.9);

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, Braund, Mr. Owen Harris to Dooley, Mr. Patrick
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.5+ KB

# %%
titanic.index
# Out:
# Index(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        ...
#        'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#        'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#        'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#        'Graham, Miss. Margaret Edith',
#        'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell',
#        'Dooley, Mr. Patrick'],
#       dtype='object', name='Name', length=891)

# %%
titanic.iloc[0:2,3:6]
# Out:
#                                                        Sex   Age  SibSp
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1

# %%
titanic.loc['Lam, Mr. Ali',"Age"]
# Out:
# nan

# %%
titanic.at['Lam, Mr. Ali',"Age"]
# Out:
# nan

# %%
titanic["Age"] > 70
# Out:
# Name
# Braund, Mr. Owen Harris                                False
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    False
# Heikkinen, Miss. Laina                                 False
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           False
# Allen, Mr. William Henry                               False
#                                                        ...
# Montvila, Rev. Juozas                                  False
# Graham, Miss. Margaret Edith                           False
# Johnston, Miss. Catherine Helen "Carrie"               False
# Behr, Mr. Karl Howell                                  False
# Dooley, Mr. Patrick                                    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic["Age"] > 70]
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# Goldschmidt, Mr. George B                      97         0       1  male
# Connors, Mr. Patrick                          117         0       3  male
# Artagaveytia, Mr. Ramon                       494         0       1  male
# Barkworth, Mr. Algernon Henry Wilson          631         1       1  male
# Svensson, Mr. Johan                           852         0       3  male
#
#                                        Age  SibSp  Parch    Ticket     Fare  \
# Name
# Goldschmidt, Mr. George B             71.0      0      0  PC 17754  34.6542
# Connors, Mr. Patrick                  70.5      0      0    370369   7.7500
# Artagaveytia, Mr. Ramon               71.0      0      0  PC 17609  49.5042
# Barkworth, Mr. Algernon Henry Wilson  80.0      0      0     27042  30.0000
# Svensson, Mr. Johan                   74.0      0      0    347060   7.7750
#
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.axes
# Out:
# [Index(['Braund, Mr. Owen Harris',
#         'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#         'Heikkinen, Miss. Laina',
#         'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#         'Allen, Mr. William Henry', 'Moran, Mr. James',
#         'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#         'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#         'Nasser, Mrs. Nicholas (Adele Achem)',
#         ...
#         'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#         'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#         'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#         'Graham, Miss. Margaret Edith',
#         'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell',
#         'Dooley, Mr. Patrick'],
#        dtype='object', name='Name', length=891),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#         'Ticket', 'Fare', 'Cabin', 'Embarked'],
# ...

# %%
titanic.iloc[0:10]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass     Sex   Age  \
# Name
# ...

# %%
titanic.iloc[0:10]["Age"].mean()
# Out:
# 28.11111111111111

# %%
print(titanic.groupby("Survived")["Age"].mean())
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic[titanic["Age"] > titanic["Age"].mean()]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# McCarthy, Mr. Timothy J                                       7         0
# Bonnell, Miss. Elizabeth                                     12         1
# ...                                                         ...       ...
# Vander Cruyssen, Mr. Victor                                 874         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Markun, Mr. Johann                                          882         0
# Rice, Mrs. William (Margaret Norton)                        886         0
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
runners = pd.DataFrame([
              {'Runner': 'Runner 1', 400: 64, 800: 128, 1200: 192, 1500: 240},
              {'Runner': 'Runner 2', 400: 80, 800: 160, 1200: 240, 1500: 300},
              {'Runner': 'Runner 3', 400: 96, 800: 192, 1200: 288, 1500: 360},
          ])

# %%
runners
# Out:
#      Runner  400  800  1200  1500
# 0  Runner 1   64  128   192   240
# 1  Runner 2   80  160   240   300
# 2  Runner 3   96  192   288   360

# %%
runners = pd.melt(runners, id_vars="Runner",
              value_vars=[400, 800, 1200, 1500],
              var_name="distance",
              value_name="time"
          )

# %%
runners
# Out:
#       Runner distance  time
# 0   Runner 1      400    64
# 1   Runner 2      400    80
# 2   Runner 3      400    96
# 3   Runner 1      800   128
# 4   Runner 2      800   160
# 5   Runner 3      800   192
# 6   Runner 1     1200   192
# 7   Runner 2     1200   240
# 8   Runner 3     1200   288
# 9   Runner 1     1500   240
# 10  Runner 2     1500   300
# 11  Runner 3     1500   360

# %% [markdown]
# # Working with dataframes

# %%
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.050203  0.342826  0.326871  0.737704
# 2013-01-02 -0.029888 -1.630498  0.368263 -1.000179
# 2013-01-03  0.311541 -0.666323  0.669504 -1.708307
# 2013-01-04 -0.064353  0.547875  1.281267 -0.711980
# 2013-01-05 -0.351895 -0.817318  1.426438  1.846292
# 2013-01-06 -0.231590 -0.386963 -0.738168  0.553748

# %%
df = pd.DataFrame({'A': ['dog', 'cat', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog'],
                   'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                   'C': np.array([3] * 8, dtype='int32'),
                   'D': np.random.randn(8),
                   'E': np.random.randn(8)})

# %%
df
# Out:
#      A      B  C         D         E
# 0  dog    one  3  0.598065 -2.242153
# 1  cat    one  3  0.091628  0.679763
# 2  dog    two  3  0.034881 -0.934458
# 3  cat  three  3  0.334064  0.319582
# 4  dog    two  3  0.848293  1.268016
# 5  cat    two  3 -0.792024 -0.296891
# 6  dog    one  3 -1.739165  1.218589
# 7  dog  three  3 -0.517279 -0.844175

# %%
sub1, sub2, sub3 = df[:2], df[2:4], df[4:]
pd.concat([sub1, sub2, sub3])
# Out:
#      A      B  C         D         E
# 0  dog    one  3 -0.165644  0.418058
# 1  cat    one  3  1.610517 -0.082369
# 2  dog    two  3  0.210559  0.057013
# 3  cat  three  3 -0.271110  1.361780
# 4  dog    two  3 -0.826592 -0.632747
# 5  cat    two  3 -0.122326 -0.096482
# 6  dog    one  3  1.481481 -0.737009
# 7  dog  three  3  0.810650 -0.006706

# %%
age = pd.DataFrame([
    {"Runner": "Runner 4", "Age": 18},
    {"Runner": "Runner 2", "Age": 21},
    {"Runner": "Runner 1", "Age": 23},
    {"Runner": "Runner 3", "Age": 19},
])

# %%
age
# Out:
#      Runner  Age
# 0  Runner 4   18
# 1  Runner 2   21
# 2  Runner 1   23
# 3  Runner 3   19

# %%
# Add the age for each runner
runners.merge(age, on="Runner")
# Out:
#       Runner distance  time  Age
# 0   Runner 1      400    64   23
# 1   Runner 1      800   128   23
# 2   Runner 1     1200   192   23
# 3   Runner 1     1500   240   23
# 4   Runner 2      400    80   21
# 5   Runner 2      800   160   21
# 6   Runner 2     1200   240   21
# 7   Runner 2     1500   300   21
# 8   Runner 3      400    96   19
# 9   Runner 3      800   192   19
# 10  Runner 3     1200   288   19
# 11  Runner 3     1500   360   19

# %%
titanic["Child"] = titanic["Age"] < 12

# %%
titanic
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic.groupby(["Sex", "Child"])["Survived"].mean()
# Out:
# Sex     Child
# female  False    0.758865
#         True     0.593750
# male    False    0.164510
#         True     0.555556
# Name: Survived, dtype: float64

# %%
titanic["SibSp"]
# Out:
# Name
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Allen, Mr. William Henry                               0
#                                                       ..
# Montvila, Rev. Juozas                                  0
# Graham, Miss. Margaret Edith                           0
# Johnston, Miss. Catherine Helen "Carrie"               1
# Behr, Mr. Karl Howell                                  0
# Dooley, Mr. Patrick                                    0
# Name: SibSp, Length: 891, dtype: int64

# %%
titanic[titanic["SibSp"] > 5]
# Out:
#                                    PassengerId  Survived  Pclass     Sex  Age  \
# Name
# Sage, Master. Thomas Henry                 160         0       3    male  NaN
# Sage, Miss. Constance Gladys               181         0       3  female  NaN
# Sage, Mr. Frederick                        202         0       3    male  NaN
# Sage, Mr. George John Jr                   325         0       3    male  NaN
# Sage, Miss. Stella Anna                    793         0       3  female  NaN
# Sage, Mr. Douglas Bullen                   847         0       3    male  NaN
# Sage, Miss. Dorothy Edith "Dolly"          864         0       3  female  NaN
#
#                                    SibSp  Parch    Ticket   Fare Cabin  \
# Name
# Sage, Master. Thomas Henry             8      2  CA. 2343  69.55   NaN
# Sage, Miss. Constance Gladys           8      2  CA. 2343  69.55   NaN
# Sage, Mr. Frederick                    8      2  CA. 2343  69.55   NaN
# ...

# %%
titanic.SibSp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
titanic[titanic["SibSp"] > 5].index
# Out:
# Index(['Sage, Master. Thomas Henry', 'Sage, Miss. Constance Gladys',
#        'Sage, Mr. Frederick', 'Sage, Mr. George John Jr',
#        'Sage, Miss. Stella Anna', 'Sage, Mr. Douglas Bullen',
#        'Sage, Miss. Dorothy Edith "Dolly"'],
#       dtype='object', name='Name')

# %%
titanic["poor"] = titanic["Fare"] < titanic["Fare"].mean()

# %%
titanic["poor"]
# Out:
# Name
# Braund, Mr. Owen Harris                                 True
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    False
# Heikkinen, Miss. Laina                                  True
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           False
# Allen, Mr. William Henry                                True
#                                                        ...
# Montvila, Rev. Juozas                                   True
# Graham, Miss. Margaret Edith                            True
# Johnston, Miss. Catherine Helen "Carrie"                True
# Behr, Mr. Karl Howell                                   True
# Dooley, Mr. Patrick                                     True
# Name: poor, Length: 891, dtype: bool

# %%
titanic
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic.hist("SibSp")
# Out:
# array([[<AxesSubplot: title={'center': 'SibSp'}>]], dtype=object)

# %%
titanic[titanic["poor"] == True].hist("SibSp")
# Out:
# array([[<AxesSubplot: title={'center': 'SibSp'}>]], dtype=object)

# %%
titanic[titanic["poor"] == False].hist("SibSp")
# Out:
# array([[<AxesSubplot: title={'center': 'SibSp'}>]], dtype=object)

# %%
titanic[titanic["poor"] == False]["SibSp"].mean()
# Out:
# 1.037914691943128

# %%
titanic[titanic["poor"] == True]["SibSp"].mean()
# Out:
# 0.36323529411764705

# %%
# File → Open from URL → enter https://api.nobelprize.org/v1/laureate.csv
# This opens it in JupyterLab but also saves it as laureate.csv
nobel = pd.read_csv("laureate.csv")
nobel.head()
# Out:
#    id       firstname    surname        born        died  \
# 0   1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1   2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2   3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3   4           Henri  Becquerel  1852-12-15  1908-08-25
# 4   5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode   diedCity gender  year category  \
# 0          Germany              DE     Munich   male  1901  physics
# 1  the Netherlands              NL        NaN   male  1902  physics
# ...

# %%
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 989 non-null    int64
#  1   firstname          988 non-null    object
#  2   surname            956 non-null    object
#  3   born               988 non-null    object
#  4   died               989 non-null    object
#  5   bornCountry        956 non-null    object
#  6   bornCountryCode    956 non-null    object
#  7   bornCity           951 non-null    object
#  8   diedCountry        642 non-null    object
#  9   diedCountryCode    642 non-null    object
#  10  diedCity           636 non-null    object
#  11  gender             989 non-null    object
#  12  year               989 non-null    int64
#  13  category           989 non-null    object
#  14  overallMotivation  23 non-null     object
#  15  share              989 non-null    int64
# ...

# %%
# the errors='coerce' argument is needed because the dataset is a bit messy
nobel["born"] = pd.to_datetime(nobel["born"], errors ='coerce')
nobel["died"] = pd.to_datetime(nobel["died"], errors ='coerce')
nobel["year"] = pd.to_datetime(nobel["year"], format="%Y")

# %%
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 989 non-null    int64
#  1   firstname          988 non-null    object
#  2   surname            956 non-null    object
#  3   born               948 non-null    datetime64[ns]
#  4   died               655 non-null    datetime64[ns]
#  5   bornCountry        956 non-null    object
#  6   bornCountryCode    956 non-null    object
#  7   bornCity           951 non-null    object
#  8   diedCountry        642 non-null    object
#  9   diedCountryCode    642 non-null    object
#  10  diedCity           636 non-null    object
#  11  gender             989 non-null    object
#  12  year               989 non-null    datetime64[ns]
#  13  category           989 non-null    object
#  14  overallMotivation  23 non-null     object
# ...

# %%
nobel["born"].dt.day
# Out:
# 0      27.0
# 1      18.0
# 2      25.0
# 3      15.0
# 4      15.0
#        ...
# 984     NaN
# 985     NaN
# 986    13.0
# 987     NaN
# 988    22.0
# Name: born, Length: 989, dtype: float64

# %%
nobel["born"].dt.year
# Out:
# 0      1845.0
# 1      1853.0
# 2      1865.0
# 3      1852.0
# 4      1859.0
#         ...
# 984       NaN
# 985       NaN
# 986    1953.0
# 987       NaN
# 988    1955.0
# Name: born, Length: 989, dtype: float64

# %%
nobel["born"].dt.weekday
# Out:
# 0      3.0
# 1      0.0
# 2      3.0
# 3      2.0
# 4      6.0
#       ...
# 984    NaN
# 985    NaN
# 986    6.0
# 987    NaN
# 988    6.0
# Name: born, Length: 989, dtype: float64

# %%
nobel["lifespan"] = round((nobel["died"] - nobel["born"]).dt.days / 365, 1)

# %%
nobel["lifespan"]
# Out:
# 0      77.9
# 1      74.6
# 2      78.4
# 3      55.7
# 4      47.0
#        ...
# 984     NaN
# 985     NaN
# 986     NaN
# 987     NaN
# 988     NaN
# Name: lifespan, Length: 989, dtype: float64

# %%
nobel.hist(column='lifespan', bins=25, rwidth=0.9)
# Out:
# array([[<AxesSubplot: title={'center': 'lifespan'}>]], dtype=object)

# %%
nobel.boxplot(column="lifespan", by="category")
# Out:
# <AxesSubplot: title={'center': 'lifespan'}, xlabel='category'>
